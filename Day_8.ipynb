# %% [markdown]
# <a href="https://colab.research.google.com/github/Anisha31415/dsml/blob/main/Day_8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Conditional statement

# %%
number = 10

if(number > 20):
  print("here")
else:
  print("there")
# Out:
# there

# %%
age = 10
if(age <=12):
  print("Travel for free")
else:
  print("pay for ticket")
# Out:
# Travel for free

# %%
age = 25
if age <=12:
  print("child")
elif age<=19:
 print("Teenage")
elif age<=35:
  print("Young adult")
else:
 print("Adult")
# Out:
# Young adult

# %%
#voting machine class task input fronm user vote halni
age= int (input ("Enter your age"))
# Out:
# Enter your age20

# %%
age=int(input("Enter your age:"))
if (age >=18):
  citizenship=input("Do you have a citizenship?")
  if(citizenship.lower()=="yes"):
   print("eligible to vote")
  else:
   print("you are not eligible to vote")
else:
  print(" you are under 18")
# Out:
# Enter your age:20
# Do you have a citizenship?yes
# eligible to vote

# %%
age= int(input("Enter your age"))
if (age>=60):
  membership=input("Do you have a membership")
  if membership.lower()=="yes":
   print("you get a  30% discount")
  elif membership.lower()=="no":
   print("you get a 20% discount")
  else:
   print("no discount")
# Out:
# Enter your age65
# Do you have a membershipyes
# you get a  30% discount

# %%
# only for  boolean checking
age = 70
is_member = True

if age>=60:
  if is_member:
    print("30% senior discount")
  else:
    print("20% senior discount")
else:
     print("Not eligible for asenior discount")
# Out:
# 30% senior discount

# %%
if (condition)
 true
else
 false

# %%
# ternary operator value if (condition) else value
n=int(input("Enter a number "))
print("even"if(n%2==0) else"odd")
# Out:
# Enter a number 2
# even

# %%
marks=float(input("enter your marks"))

if marks >= 80 and marks <= 100:
    print("Grade A")
elif marks >= 60 and marks <= 79:
    print("Grade B")
elif marks >= 40 and marks <= 59:
    print("Grade C")
elif marks >= 0 and marks < 40:
    print("Grade D")
else:
    print("Invalid marks! Please enter marks between 0 and 100.")
# Out:
# enter your marks90
# Grade A

# %%
#and operator
age = 20
citizenship = True
if age>=18 and citizenship:
  print("Eligible to vote")
else:
  print("not eligible")
# Out:
# Eligible to vote

# %%
#or operator
username="admin"
password="1234"

if username =="admin" or password=="admin123":
  print("Access granted")
else:
  print("not granted")
# Out:
# Access granted

# %%
age=int(input("Enter your age:"))
citizenship=input("Do you have a citizenship?")

if age>=18 and citizenship.lower()=="yes":
   print("eligible to vote")
else:
   print("you are not eligible to vote")
# Out:
# Enter your age:20
# Do you have a citizenship?yes
# eligible to vote

# %%
n=int(input("Enter a number"))

if n%2==0 and n>0:
  print("positive even number")
else:
  print("not positive even number")
# Out:
# Enter a number10
# positive even number

# %%
login =False

if not login:
  print("true")
else:
  print("false")
# Out:
# true

# %%
age= 20
if age>=18 and age<60:
  print("True")
else:
  print("False")
# Out:
# True

# %%
day=input("Enter the day")

if day == "Saturday" or day == "Sunday":
    print("It is a weekend.")
else:
    print("It is a weekday.")
# Out:
# Enter the daySaturday
# It is a weekend.

# %%
#&& and
#||or
#any at least one condition meet
#all whole condition must meet
