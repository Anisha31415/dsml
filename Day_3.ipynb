# %% [markdown]
# <a href="https://colab.research.google.com/github/Anisha31415/dsml/blob/main/Day_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a= 5 #initializing integer number
b= 6.4 #initializing float number
c= 3+7j  #initializing complex number

# %%
print(type(a)) #int
# Out:
# <class 'int'>

# %%
print(a==b) #false || boolean value
# Out:
# False

# %%
d= 17
print(d//a) #3 ||floor divisor:
print(a+d) #20
# Out:
# 3
# 22

# %%
b =int(b)
print(type(b)) #int
# Out:
# <class 'int'>

# %%
#Using Math Function
import math

floor= math.floor(44.9)
ceil = math.ceil(44.9)
print(f"floor={floor} and ceil= {ceil}")
# Out:
# floor=44 and ceil= 45

# %%
#finding gcd
math.gcd(4,6,12,8)
# Out:
# 2

# %%
#finding the minimum & maximum among numbers

minm = min(a,b,d)
maxm= max(a,d,b)
print(f"minimum= {minm} and maximum= {maxm}")
# Out:
# minimum= 5 and maximum= 17

# %%
name = 'Ani' #single quote string
university = "Tribhuvan University"
print(f"{name} studies in {university}")
# Out:
# Ani studies in Tribhuvan University

# %%
text1 = "wow, a lovely day" #creating a string using double quote
text2 = 'hello' #creating a string using double quote

# %%
#creating a string using triple quote
poem = '''In every line of code,a lesson grows,
Through every bug, a deeper wisdom flows.
Small steps each day become a journey bright,
Turning curiosity into skill and light.'''

# %%
#string concatenation
print(text1+", "+text2) #wow, a lovely day, hello
# Out:
# wow, a lovely day, hello

# %%
#string Repetation
print(text2 * 3) #hellohellohello (repeates the string 3 times)
# Out:
# hellohellohello

# %%
#indexing
print(text2[1]) #e
print(text2[-1]) #o
# Out:
# e
# o

# %%
#slicing [start: stop: step] || step = no of position to move each time default is 1.
print(text2[0:3]) #hel
print(text2[2:-1]) #ll
print(text2[::-1]) #olleh (reverse the string)
# Out:
# hel
# ll
# olleh

# %%
print(text1[2:16:2]) #w  oeyd
# Out:
# w  oeyd

# %%
#length using len()
print(len(poem)) #166
# Out:
# 165

# %%
#string methods
word1="fantastic"
word2="REGULAR"
word = "i am a student"

# %%
print(word1.upper()) #FANTASTIC
print(word2.lower()) #regular
print(word.title()) #I Am A Student
# Out:
# FANTASTIC
# regular
# I Am A Student

# %%
#strip() || It removes extra space/character before and after string
dummy = "   i think he is smart  "
print(dummy.strip())  #i think he is smart
sample = "&&&&&&&&brother&sister&&&&"
print(sample.strip("&")) #brother&sister
# Out:
# i think he is smart
# brother&sister

# %%
#replace
template ="he is a very good student"
print(template.replace("he","she")) #she is a very good student
# Out:
# she is a very good student

# %%
#split() || it changes string to list
fruit = "mango, banana, apple"
print(type(fruit))     #<class 'str'>
# Out:
# <class 'str'>

# %%
print(fruit.split())  #['mango,', 'banana,', 'apple']
print(type(fruit.split())) #<class 'list'>
# Out:
# ['mango,', 'banana,', 'apple']
# <class 'list'>

# %%
words="range/ml/ai/python/dsml/github" #split() splits in each "/"
print(words.split("/")) #['range', 'man', 'ai', 'python', 'dsml', 'github']
# Out:
# ['range', 'ml', 'ai', 'python', 'dsml', 'github']

# %%
#join() || It changes list into string
joint = ['range', 'ml', 'ai', 'python', 'dsml', 'github']
print(", ".join(joint))  #range, man, ai, python, dsml, github
# Out:
# range, ml, ai, python, dsml, github

# %%
fav = ["P","y","t","h","o","n"]
print("".join(fav)) #Python
# Out:
# Python
