# %% [markdown]
# <a href="https://colab.research.google.com/github/Anisha31415/dsml/blob/main/Day_16.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#iterable
num={1,2,3}
it = iter(num)

# %%
print(next(it))
# Out:
# 3

# %%
#iterable
lst=[1,2,3]
for i in lst:
 print(i)
# Out:
# 1
# 2
# 3

# %%
num=[1,2,3]
it = iter(num)

# %%
it

# %%
next(it)
# Out:
# 1

# %%
for i in it:
  print(i)
# Out:
# 1
# 2
# 3

# %%
def count_up(n):
  i=1
  while i<=n:
    yield i # yield is use for extract element one by one
    i+=1

# %%
gent = count_up(3)

# %%
gent
# Out:
# <generator object count_up at 0x7f078e102a40>

# %%
print (next(gent))
# Out:
# 2

# %%
print(next(gent))
# Out:
# 3

# %%
#Practice Question
def data():
  def number():
    return x+y

# %%
#error handling in python
#try,except, else and finally

try:
  numerator =int(input("Ejknnnter a number to divide"))
  denominator= int(input("Enter a number to divide by:"))
  result=numerator/denominator
except ZeroDivisionError:
   print("Zero:Cannot divide by zero!")
except ValueError:
   print("Error:Invalid input. Please enter a valid number")
else:
  print(f"The result is{result}")
finally:
  print("Execution Complete")
# Out:
# Enter a number to dividejkkk
# Error:Invalid input. Please enter a valid number
# Execution Complete

# %%
#ZeroDivision Error
num=10
result =num/0
print(result)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# /tmp/ipykernel_797/4275553054.py in <cell line: 0>()
#       1 #ZeroDivision Error
#       2 num=10
# ----> 3 result =num/0
#       4 print(result)
#
# ZeroDivisionError: division by zero

# %%
#Type error
num=0
lst ="colab"
result= num+lst
print(result)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_797/3721616516.py in <cell line: 0>()
#       2 num=0
#       3 lst ="colab"
# ----> 4 result=num+lst
#       5 print(result)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
#indexError
lst=[1,2,3,4]
print(lst[5])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_797/2136475293.py in <cell line: 0>()
#       1 #indexError
#       2 lst=[1,2,3,4]
# ----> 3 print(lst[5])
#
# IndexError: list index out of range

# %%
#Value Error
num=int("abc")
print(num)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_797/3472774831.py in <cell line: 0>()
#       1 #Value Error
# ----> 2 num=int("abc")
#       3 print(num)
#
# ValueError: invalid literal for int() with base 10: 'abc'
