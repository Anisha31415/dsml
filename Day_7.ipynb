# %% [markdown]
# <a href="https://colab.research.google.com/github/Anisha31415/dsml/blob/main/Day_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#dict()
dict_data=dict({
    "name":"Anisha",
    "address":"Pkr",
    "phone":"1111111"
})

# %%
dict_data
# Out:
# {'name': 'Anisha', 'address': 'Pkr', 'phone': '1111111'}

# %%
person= dict([("name","Anisha"),("Address","Pkr")])
person
# Out:
# {'name': 'Anisha', 'Address': 'Pkr'}

# %%
dict_data["phone"]
# Out:
# '1111111'

# %%
dict_data.get("phone")
# Out:
# '1111111'

# %%
dict_data=dict({
    "name":"Anisha",
    "address":"Pkr",
    "phone":"1111111"
})

# %%
#keys()
dict_data.keys()
# Out:
# dict_keys(['name', 'address', 'phone'])

# %%
# values()
dict_data.values()
# Out:
# dict_values(['Anisha', 'Pkr', '1111111'])

# %%
#items()
dict_data.items()
# Out:
# dict_items([('address', 'Pkr')])

# %%
#pop
dict_data.pop("name","Not Found" )
# Out:
# 'Not Found'

# %%
dict_data.pop("address")
# Out:
# 'Pkr'

# %%
dict_data.pop("address", "Not Found")
# Out:
# 'Not Found'

# %%
dict_data=dict({
    "name":"Anisha",
    "address":"Pkr",
    "phone":"1111111"
})

# %%
#pop.item()dict_data.popitem()
# Out:
# ('phone', '1111111')

# %%
dict_data
# Out:
# {'name': 'Anisha', 'address': 'Pkr'}

# %%
#removes the key value pair but return error
del dict_data['name']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_1020/3370217295.py in <cell line: 0>()
# ----> 1 del dict_data['name']
#
# KeyError: 'name'

# %%
dict_data
# Out:
# {'address': 'Pkr'}

# %%
dict1={
    "name":"riya",
    "address":"Ktm",
    "age":20
}
dict1
# Out:
# {'name': 'riya', 'address': 'Ktm', 'age': 20}

# %%
dict2 ={
    "phone":928366,
    "skill":"DSML"
}

# %%
dict1.update(dict2)
dict1
# Out:
# {'name': 'riya', 'address': 'Ktm', 'age': 20, 'phone': 928366, 'skill': 'DSML'}

# %%
dict3={
    "gender":"female",
    "marks": 80
}

# %%
student_dict={**dict1,**dict2, **dict3}#using kwargs to unpack
student_dict
# Out:
# {'name': 'riya',
#  'address': 'Ktm',
#  'age': 20,
#  'phone': 928366,
#  'skill': 'DSML',
#  'gender': 'female',
#  'marks': 80}

# %%
dict4={
    "course":"DSML"

  }

# %%
student_dict={**dict1,**dict2, **dict3,**dict4}
student_dict
# Out:
# {'name': 'riya',
#  'address': 'Ktm',
#  'age': 20,
#  'phone': 928366,
#  'skill': 'DSML',
#  'gender': 'female',
#  'marks': 80,
#  'course': 'DSML'}

# %%
result = sorted(student_dict)
result
# Out:
# ['address', 'age', 'course', 'gender', 'marks', 'name', 'phone', 'skill']

# %%
# only sorts the keys
student = {"b":2,"a":1, "c":3}
result=sorted(student)
result
# Out:
# ['a', 'b', 'c']

# %%
#merge dict
dict1| dict2| dict3
# Out:
# {'name': 'riya',
#  'address': 'Ktm',
#  'age': 20,
#  'phone': 928366,
#  'skill': 'DSML',
#  'gender': 'female',
#  'marks': 80}

# %%
len(dict1)
# Out:
# 5

# %%
# setdefault checks the key if found return its value else print the given message and add
#the key-value pair
dict1.setdefault("name","default value")
# Out:
# 'riya'

# %%
dict1.setdefault("course","default value")
# Out:
# 'default value'

# %%
dict1
# Out:
# {'name': 'riya',
#  'address': 'Ktm',
#  'age': 20,
#  'phone': 928366,
#  'skill': 'DSML',
#  'hello': 'this is hello',
#  'course': 'default value'}

# %%
"age" in dict1.keys()
# Out:
# True

# %%
#max and min in dictionary
dict={
    "A":30,
    "B":35,
    "C":20
}
print(max(dict.values()))
print(min(dict.values()))
# Out:
# 35
# 20

# %%
#Task
dict_datas={
    "name":"Isha",
    "age":20,
    "faculty":"IT"
}
dict_datas
# Out:
# {'name': 'Isha', 'age': 20, 'faculty': 'IT'}

# %%
dict_datas["phone"]=983445666
dict_datas
# Out:
# {'name': 'Isha', 'age': 20, 'faculty': 'IT', 'phone': 983445666}

# %%
dict_datas["age"]=18
dict_datas
# Out:
# {'name': 'Isha', 'age': 18, 'faculty': 'IT', 'phone': 983445666}

# %%
dict_datas["city"]="Ktm"
dict_datas
# Out:
# {'name': 'Isha', 'age': 18, 'faculty': 'IT', 'phone': 983445666, 'city': 'Ktm'}

# %%
del dict_datas["city"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_1020/1993840822.py in <cell line: 0>()
# ----> 1 del dict_datas["city"]
#
# KeyError: 'city'

# %%
dict_datas
# Out:
# {'name': 'Isha', 'age': 18, 'faculty': 'IT', 'phone': 983445666}
