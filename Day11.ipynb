# %% [markdown]
# <a href="https://colab.research.google.com/github/Anisha31415/dsml/blob/main/Day11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Python user defined function

# %%
def number():
  a=int(input("enter a number"))
  b=int(input("enter a number"))
  c=int(input("enter a number"))
  if a > b and a > c:
   print("A"," is the largest")
  elif b > a and b > c:
   print("B", "is the largest")
  elif c > a and c > b:
   print("C", "is the largest")
  else:
    print("Error")

number()
# Out:
# enter a number7
# enter a number6
# enter a number5
# A  is the largest

# %%
def vowels(text):
  vowels = "aeiouAEIOU"
  count = 0

  for char in text:
    if char in vowels:
       count += 1

  return count

# User input
string = input("Enter a string: ")

# Function call
result = vowels(string)

print("Number of vowels:", result)
# Out:
# Enter a string: hi
# Number of vowels: 1

# %%
def data():
  value = (input("Enter a sentence"))
  return value

# %%
data()
# Out:
# Enter a sentence6
# '6'

# %%
#Built in function
#Hello World"
#Hello-World"
#Hello-World" \n for new line
print("Hello", "World", sep="-",end=".")
print("\nHello\nworld")
# Out:
# Hello-World.
# Hello
# world

# %%
type(1)
# Out:
# int

# %%
type(4==2)
# Out:
# bool

# %%
#len()
lst = [1,2,3,4,5,6]
len(lst)
# Out:
# 6

# %%
#dir
x="riya"
print(dir(x))
# Out:
# ['__add__', '__class__', '__contains__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getnewargs__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__mod__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__rmod__', '__rmul__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', 'capitalize', 'casefold', 'center', 'count', 'encode', 'endswith', 'expandtabs', 'find', 'format', 'format_map', 'index', 'isalnum', 'isalpha', 'isascii', 'isdecimal', 'isdigit', 'isidentifier', 'islower', 'isnumeric', 'isprintable', 'isspace', 'istitle', 'isupper', 'join', 'ljust', 'lower', 'lstrip', 'maketrans', 'partition', 'removeprefix', 'removesuffix', 'replace', 'rfind', 'rindex', 'rjust', 'rpartition', 'rsplit', 'rstrip', 'split', 'splitlines', 'startswith', 'strip', 'swapcase', 'title', 'translate', 'upper', 'zfill']

# %%
#open()
file = open("/content/Assignment_1.ipynb", mode="r")
print(file.read())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_757/3832818829.py in <cell line: 0>()
#       1 #open()
# ----> 2 file = open("/content/Assignment_1.ipynb", mode="r")
#       3 print(file.read())
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/Assignment_1.ipynb'

# %%
file.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_757/958367565.py in <cell line: 0>()
# ----> 1 file.close()
#
# NameError: name 'file' is not defined

# %%
file.read()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_757/1407933502.py in <cell line: 0>()
# ----> 1 file.read()
#
# NameError: name 'file' is not defined

# %%
file = open(".txt",mode="w")
file.write("Welcome to dsml class")
# Out:
# 21

# %%
open('dummyprint(file.read())

# %%
with open("/content/Assignment_1.ipynb", mode ="r+") as file:
  #file.seek(0)
 file.write("Anisha")
 print(file.read())
 dictionary={name:"}
# Out:
# bformat": 4,
#   "nbformat_minor": 0,
#   "metadata": {
#     "colab": {
#       "provenance": []
#     },
#     "kernelspec": {
#       "name": "python3",
#       "display_name": "Python 3"
#     },
#     "language_info": {
#       "name": "python"
#     }
#   },
#   "cells": [
#     {
#       "cell_type": "code",
#       "execution_count": null,
#       "metadata": {
#         "colab": {
#           "base_uri": "https://localhost:8080/",
#           "height": 124
#         },
#         "id": "g2t7_TEnRkPY",
#         "outputId": "2d10a9c9-8742-4703-a4ef-e1d5092b0839"
#       },
#       "outputs": [
#         {
#           "output_type": "error",
#           "ename": "SyntaxError",
#           "evalue": "unterminated string literal (detected at line 1) (2488266683.py, line 1)",
#           "traceback": [
# ...

# %%
lst =[1,2,3,4,5,6]
for index, num in enumerate(lst):
  print(num)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6

# %%
#enumerate
names =["Riya","Sina","Priya","Nisha"]
for (i,name) in enumerate(names):
  print(f"{name}:Roll{i}")
# Out:
# Riya:Roll0
# Sina:Roll1
# Priya:Roll2
# Nisha:Roll3

# %%
name=["Riya","Sina","Priya","Nisha"]
for (i,name) in enumerate(names, start=1):
  print(f"{name}:Roll{i}")
# Out:
# Riya:Roll1
# Sina:Roll2
# Priya:Roll3
# Nisha:Roll4

# %%
data1 = [1,2,3,4,5]
data2 = ["A", "B", "C", "D", "E"]

for (data,num) in zip(data1,data2):
  print(data,num, sep="->")
# Out:
# 1->A
# 2->B
# 3->C
# 4->D
# 5->E
