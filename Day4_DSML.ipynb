# %% [markdown]
# <a href="https://colab.research.google.com/github/Anisha31415/dsml/blob/main/Day4_DSML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
data="Hello"

# %%
type[data]
# Out:
# type['Hello']

# %%
data 1+"Anisha"
# Out:
#   File "/tmp/ipykernel_5506/1250843577.py", line 1
#     data 1+"Anisha"
#          ^
# SyntaxError: invalid syntax

# %%
data1="Anisha"

# %%
data +""data1
# Out:
#   File "/tmp/ipykernel_5506/739122246.py", line 1
#     data +""data1
#             ^
# SyntaxError: invalid syntax

# %%
data1 *3
# Out:
# 'AnishaAnishaAnisha'

# %%
data2= "python"

# %%
data_[1]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_5506/436208611.py in <cell line: 0>()
# ----> 1 data_[1]
#
# NameError: name 'data_' is not defined

# %%
data2_[1]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_5506/227373991.py in <cell line: 0>()
# ----> 1 data2_[1]
#
# NameError: name 'data2_' is not defined

# %%
data2[1]
# Out:
# 'y'

# %%
data="Python"

# %%
data[1]+data[2]
# Out:
# 'yt'

# %%
data[3:]
# Out:
# 'hon'

# %%
data[::-11]
# Out:
# 'n'

# %%
data[::-1]
# Out:
# 'nohtyP'

# %%
data_n="Hello, i am from these class"
len(data_n)
# Out:
# 28

# %%
string ="Hello"
string.upper()
# Out:
# 'HELLO'

# %%
string1="Hello"
string.title()
# Out:
# 'Hello'

# %%
string2="hello"
string.title()
# Out:
# 'Hello'

# %%
string3='hello'
string.strip()
# Out:
# 'Hello'

# %%
string4 = " hello  world "
string4.strip()
# Out:
# 'hello  world'

# %%
string4="he   llo"
string4.strip()
# Out:
# 'he   llo'

# %%
text="####Python####"
text.strip("#")
# Out:
# 'Python'

# %%
#replace
text="I like java"
text.replace("java","python")
# Out:
# 'I like python'

# %%
#split
text = "apple, banana, mango"
text.split(",")
# Out:
# ['apple', ' banana', ' mango']

# %%
text = "apple, banana, mango"#splits a string into a list
text.split("a")
# Out:
# ['', 'pple, b', 'n', 'n', ', m', 'ngo']

# %%
# join
letters= ["P","Y","T","H","O","N"] #list
print("".join(letters))
# Out:
# PYTHON

# %%
letters= ["P","Y","T","H","O","N"]
print(" ".join(letters))
# Out:
# P Y T H O N
